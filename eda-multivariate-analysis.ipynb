# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  mapsko mount ville   sector 79   1.10         12732.0
# 1          flat       ansal estella  sector 103   1.50          8670.0
# 2          flat         mrg skyline  sector 106   1.82         13392.0
# 3          flat          chd avenue   sector 71   0.95          7929.0
# 4          flat         ats triumph  sector 104   1.75          7641.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1359.0  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3
# 3  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 4  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       4.0        East           Undefined
# 3         2       2       5.0       South      Moderately Old
# 4         4      3+      12.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2                  NaN         1359.0       952.00           0             0
# 3               1198.0            NaN          NaN           0             0
# 4               2290.0            NaN      1800.00           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                0             0
# 3           0           0       0                1           142
# 4           0           1       1                1            21

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 325          house           vipul tatvam villa  sector 48   7.25
# 474          house                  independent   sector 4   0.60
# 620          house     unitech uniworld resorts  sector 33  10.00
# 989          house                   ardee city  sector 52   5.50
# 1212         house                  independent  sector 54   3.75
# 1312         house     unitech uniworld resorts  sector 33   9.50
# 1605          flat           ambience caitriona  sector 24  14.00
# 1724         house                    rk excelo  sector 12   0.60
# 1862         house                  independent  sector 38   8.00
# 1917         house            vatika india next  sector 82   7.00
# 2112         house       dlf city plots phase 2  sector 25  10.50
# 2128         house         bhim nagar, sector 6   sector 6   0.85
# 2362         house  unitech nirvana birch court  sector 50   7.10
# 2370         house                  independent  sector 57   8.00
# 2436         house                        ansal  sector 43   1.85
# 2501         house                dlf the grove  sector 54   5.70
# 2509         house                  independent  sector 23   2.80
# 2606         house                  independent  sector 12   6.00
# 2695         house       emaar the palm springs  sector 54  24.00
# 2720         house                  independent  sector 17   3.50
# 2769         house                  independent  sector 12   3.50
# 2770         house                  independent  sector 28   4.50
# 2813         house         eros rosewood villas  sector 49   2.75
# 2982         house          huda plot sector 38  sector 38   4.30
# 3115         house       unitech deerwood chase  sector 50   8.45
# 3317         house               uppal southend  sector 49   6.75
# 3339         house                  independent  sector 55   1.45
# 3432         house       dlf city plots phase 2  sector 25  10.00
# 3577         house                  independent  sector 24  10.00
#
#       price_per_sqft   area  \
# 325         201388.0  360.0
# 474         105263.0   57.0
# 620         181818.0  550.0
# 989         183333.0  300.0
# 1212        234375.0  160.0
# 1312        173992.0  546.0
# 1605        200000.0  700.0
# 1724        120000.0   50.0
# 1862        230547.0  347.0
# 1917        194444.0  360.0
# 2112        261194.0  402.0
# 2128        126865.0   67.0
# 2362        283333.0  251.0
# 2370        266666.0  300.0
# 2436        308333.0   60.0
# 2501        211111.0  270.0
# 2509        161849.0  173.0
# 2606        315789.0  190.0
# 2695        600000.0  400.0
# 2720        218750.0  160.0
# 2769        133079.0  263.0
# 2770        125000.0  360.0
# 2813        178571.0  154.0
# 2982        245398.0  175.0
# 3115        235376.0  359.0
# 3317        290948.0  232.0
# 3339        241666.0   60.0
# 3432        400000.0  250.0
# 3577        229885.0  435.0
#
#                                            areaWithType  super_built_up_area  \
# 325                          Plot area 360(33.45 sq.m.)                  NaN
# 474                             Plot area 57(5.3 sq.m.)                  NaN
# 620                           Plot area 550(51.1 sq.m.)                  NaN
# 989                          Plot area 300(27.87 sq.m.)                  NaN
# 1212                         Plot area 160(14.86 sq.m.)                  NaN
# 1312                         Plot area 546(50.73 sq.m.)                  NaN
# 1605                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1724  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1862  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 1917  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 2112                         Plot area 402(37.35 sq.m.)                  NaN
# 2128                           Plot area 67(6.22 sq.m.)                  NaN
# 2362                          Plot area 240(22.3 sq.m.)                  NaN
# 2370                         Plot area 300(27.87 sq.m.)                  NaN
# 2436                           Plot area 60(5.57 sq.m.)                  NaN
# 2501                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 2509  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 2606  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2695                         Plot area 400(37.16 sq.m.)                  NaN
# 2720                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 2769  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2770                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2813  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2982  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 3115                         Plot area 359(33.35 sq.m.)                  NaN
# 3317                         Plot area 232(21.55 sq.m.)                  NaN
# 3339                           Plot area 60(5.57 sq.m.)                  NaN
# 3432                         Plot area 250(23.23 sq.m.)                  NaN
# 3577                     Carpet area: 435 (40.41 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 325           360.0          NaN
# 474            57.0          NaN
# 620           550.0          NaN
# 989           300.0          NaN
# 1212          160.0          NaN
# 1312          546.0          NaN
# 1605          700.0          NaN
# 1724           30.0         15.0
# 1862          347.0        215.0
# 1917         3900.0       3743.0
# 2112          402.0          NaN
# 2128           67.0          NaN
# 2362          240.0          NaN
# 2370          300.0          NaN
# 2436           60.0          NaN
# 2501          270.0          NaN
# 2509          160.0        150.0
# 2606            NaN       1600.0
# 2695          400.0          NaN
# 2720          160.0          NaN
# 2769         4800.0       4400.0
# 2770          360.0          NaN
# 2813            NaN       1650.0
# 2982          145.0          NaN
# 3115          359.0          NaN
# 3317          232.0          NaN
# 3339           60.0          NaN
# 3432          250.0          NaN
# 3577            NaN        435.0

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  mapsko mount ville   sector 79   1.10         12732.0
# 1          flat       ansal estella  sector 103   1.50          8670.0
# 2          flat         mrg skyline  sector 106   1.82         13392.0
# 3          flat          chd avenue   sector 71   0.95          7929.0
# 4          flat         ats triumph  sector 104   1.75          7641.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1359.0  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3
# 3  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 4  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       4.0        East           Undefined
# 3         2       2       5.0       South      Moderately Old
# 4         4      3+      12.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2                  NaN         1359.0       952.00           0             0
# 3               1198.0            NaN          NaN           0             0
# 4               2290.0            NaN      1800.00           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                0             0
# 3           0           0       0                1           142
# 4           0           1       1                1            21

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                 society     sector  price  price_per_sqft  \
# 50           house  laxmi garden sector-11  sector 11   1.50         12820.0
# 100          house             independent  sector 56  11.95         43534.0
# 217          house             independent  sector 24   4.50         33333.0
# 256          house  luxury dlf city floors  sector 26   8.25         45833.0
# 273          house             independent  sector 43   7.50         38760.0
# ...            ...                     ...        ...    ...             ...
# 3608         house             independent  sector 26  26.00         82540.0
# 3638         house             independent  sector 13   0.50         90909.0
# 3679         house             independent  sector 28  11.00         33951.0
# 3770         house             independent  sector 55   9.19         34037.0
# 3782         house                shivpuri   sector 7   2.40          8889.0
#
#         area                                       areaWithType  bedRoom  \
# 50    1170.0                         Plot area 130(108.7 sq.m.)       12
# 100   2745.0                        Plot area 305(255.02 sq.m.)       12
# 217   1350.0  Plot area 163(136.29 sq.m.)Built Up area: 160 ...       10
# 256   1800.0                        Plot area 200(167.23 sq.m.)       12
# 273   1935.0                        Plot area 215(179.77 sq.m.)       12
# ...      ...                                                ...      ...
# 3608  3150.0  Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16
# 3638    55.0                           Plot area 55(5.11 sq.m.)       12
# 3679  3240.0                        Plot area 360(301.01 sq.m.)       13
# 3770  2700.0                        Plot area 300(250.84 sq.m.)       16
# 3782  2700.0                        Plot area 300(250.84 sq.m.)       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 50           9       1       3.0        East  Relatively New
# 100         12      3+       4.0        West  Relatively New
# 217          8      3+       4.0        East  Relatively New
# 256         12      3+       4.0       North    New Property
# 273         12      3+       4.0        East    New Property
# ...        ...     ...       ...         ...             ...
# 3608        16      3+       4.0  North-West    New Property
# 3638         4       3       4.0         NaN    Old Property
# 3679        13      3+       3.0        East  Relatively New
# 3770        18       2       4.0        West    New Property
# 3782         5       3       2.0       North    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 50                    NaN         1170.0          NaN           1
# 100                   NaN         2745.0          NaN           0
# 217                   NaN          160.0        150.0           0
# 256                   NaN         1800.0          NaN           0
# 273                   NaN         1935.0          NaN           1
# ...                   ...            ...          ...         ...
# 3608                  NaN          400.0        350.0           1
# 3638                  NaN           55.0          NaN           0
# 3679                  NaN         3240.0          NaN           1
# 3770                  NaN         2700.0          NaN           0
# 3782                  NaN         2700.0          NaN           1
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 50               1           0           1       1                1
# 100              1           0           0       0                1
# 217              1           1           0       0                1
# 256              1           0           0       0                1
# 273              1           1           1       0                1
# ...            ...         ...         ...     ...              ...
# 3608             1           1           1       0                1
# 3638             0           0           0       0                0
# 3679             1           0           1       0                2
# 3770             1           0           1       0                1
# 3782             1           0           1       0                0
#
#       luxury_score
# 50             106
# 100             21
# 217             56
# 256            105
# 273             72
# ...            ...
# 3608            72
# 3638            15
# 3679           122
# 3770            49
# 3782             8
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 51           house      ireo victory valley   sector 67   8.00
# 413          house      satya the hermitage  sector 103   3.15
# 436          house              independent   sector 92   1.80
# 717          house         suncity township   sector 54   2.00
# 1050         house               ninex city   sector 76   1.75
# 1078         house        suncity avenue 76   sector 76   0.75
# 1462         house   vatika the seven lamps   sector 82   1.60
# 1616         house              greenopolis   sector 89   0.70
# 1757         house           ats tourmaline  sector 109   1.87
# 2294         house           dlf the arbour   sector 63   8.50
# 2617         house              spaze privy   sector 72   3.10
# 3075         house  indiabulls centrum park  sector 103   3.25
# 3094         house          godrej meridien  sector 106   5.60
# 3135         house              spaze privy   sector 72   3.09
#
#       price_per_sqft    area  \
# 51           22222.0  3600.0
# 413           6702.0  4700.0
# 436           7627.0  2360.0
# 717          30968.0   646.0
# 1050          6250.0  2800.0
# 1078         10067.0   745.0
# 1462          6597.0  2425.0
# 1616          5397.0  1297.0
# 1757          8697.0  2150.0
# 2294         21519.0  3950.0
# 2617          8486.0  3653.0
# 3075          8125.0  4000.0
# 3094         14000.0  4000.0
# 3135          6981.0  4426.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 51                          Plot area 400(334.45 sq.m.)        6         7
# 413                  Built Up area: 4700 (436.64 sq.m.)        4         5
# 436                  Built Up area: 2360 (219.25 sq.m.)        4         5
# 717   Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 1050                   Carpet area: 2800 (260.13 sq.m.)        4         4
# 1078  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 1462                       Plot area 2425(225.29 sq.m.)        4         4
# 1616                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1757                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 2294                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 2617                       Plot area 3653(339.37 sq.m.)        5         5
# 3075                       Plot area 4000(371.61 sq.m.)        4         3
# 3094                       Plot area 4000(371.61 sq.m.)        5         4
# 3135  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 51        3+      51.0  North-East      Moderately Old                  NaN
# 413        0      12.0        East           Undefined                  NaN
# 436        0      13.0         NaN           Undefined                  NaN
# 717        3      11.0       North      Relatively New                  NaN
# 1050       0      14.0         NaN           Undefined                  NaN
# 1078       2      11.0  North-East        New Property                  NaN
# 1462      3+      16.0       North      Moderately Old                  NaN
# 1616       2      14.0  North-East           Undefined                  NaN
# 1757       0      12.0         NaN           Undefined                  NaN
# 2294      3+      27.0         NaN           Undefined                  NaN
# 2617      3+      21.0         NaN      Relatively New                  NaN
# 3075      3+      20.0         NaN  Under Construction                  NaN
# 3094      3+      33.0  North-East        New Property                  NaN
# 3135      3+      14.0        East      Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 51           3600.0          NaN           1             1           0
# 413          4700.0          NaN           0             0           0
# 436          2360.0          NaN           0             0           0
# 717            60.0         59.0           0             1           0
# 1050            NaN       2800.0           0             0           0
# 1078          745.0          NaN           0             0           0
# 1462         2425.0          NaN           0             1           0
# 1616         1297.0          NaN           0             0           0
# 1757         2150.0          NaN           0             0           0
# 2294         3950.0          NaN           0             0           0
# 2617         3653.0          NaN           0             0           0
# 3075         4000.0          NaN           0             0           0
# 3094         4000.0          NaN           1             1           1
# 3135         3653.0       2922.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 51             1       0                1            49
# 413            0       0                0            61
# 436            0       0                0             0
# 717            0       0                2             7
# 1050           0       0                0             0
# 1078           0       0                0            40
# 1462           0       0                0            94
# 1616           0       0                0             0
# 1757           0       0                0             0
# 2294           0       0                0            61
# 2617           0       0                0             0
# 3075           0       0                0            51
# 3094           1       0                0           151
# 3135           0       0                1            33

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  mapsko mount ville   sector 79   1.10         12732.0
# 1          flat       ansal estella  sector 103   1.50          8670.0
# 2          flat         mrg skyline  sector 106   1.82         13392.0
# 3          flat          chd avenue   sector 71   0.95          7929.0
# 4          flat         ats triumph  sector 104   1.75          7641.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1359.0  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3
# 3  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 4  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       4.0        East           Undefined
# 3         2       2       5.0       South      Moderately Old
# 4         4      3+      12.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2                  NaN         1359.0       952.00           0             0
# 3               1198.0            NaN          NaN           0             0
# 4               2290.0            NaN      1800.00           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                0             0
# 3           0           0       0                1           142
# 4           0           1       1                1            21

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  mapsko mount ville   sector 79   1.10         12732.0
# 1          flat       ansal estella  sector 103   1.50          8670.0
# 2          flat         mrg skyline  sector 106   1.82         13392.0
# 3          flat          chd avenue   sector 71   0.95          7929.0
# 4          flat         ats triumph  sector 104   1.75          7641.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1359.0  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3
# 3  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 4  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       4.0        East           Undefined
# 3         2       2       5.0       South      Moderately Old
# 4         4      3+      12.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2                  NaN         1359.0       952.00           0             0
# 3               1198.0            NaN          NaN           0             0
# 4               2290.0            NaN      1800.00           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                0             0
# 3           0           0       0                1           142
# 4           0           1       1                1            21

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat  mapsko mount ville   sector 79   1.10         12732.0
# 1          flat       ansal estella  sector 103   1.50          8670.0
# 2          flat         mrg skyline  sector 106   1.82         13392.0
# 3          flat          chd avenue   sector 71   0.95          7929.0
# 4          flat         ats triumph  sector 104   1.75          7641.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1359.0  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3
# 3  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 4  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       4.0        East           Undefined
# 3         2       2       5.0       South      Moderately Old
# 4         4      3+      12.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2                  NaN         1359.0       952.00           0             0
# 3               1198.0            NaN          NaN           0             0
# 4               2290.0            NaN      1800.00           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                0             0
# 3           0           0       0                1           142
# 4           0           1       1                1            21

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['bedRoom'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['bedRoom'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['agePossession'])
# Out:
# C:\Users\Nitish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(df['luxury_score'],df['price'])
# Out:
# C:\Users\Nitish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# built_up_area          0.551649
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.254834
# luxury_score           0.094775
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.094290
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            38
# 2           0           0       0                0            15
# 3           0           0       0                0            49
# 4           0           0       1                1           174

# %%
sns.pairplot(df)

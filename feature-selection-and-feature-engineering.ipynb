# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_missing_value_imputation.csv')

# %%
df.shape
# Out:
# (3556, 24)

# %%
df.head()
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0          flat    mapsko mount ville   sector 79   1.10         12731.0
# 1          flat         ansal estella  sector 103   1.50          8671.0
# 2          flat            chd avenue   sector 71   0.95          7930.0
# 3          flat           ats triumph  sector 104   1.75          7642.0
# 4          flat  breez global heights  sohna road   0.46          6479.0
#
#      area                                       areaWithType  bedRoom  \
# 0   864.0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3
# 1  1730.0  Super Built up area 1730(160.72 sq.m.)Carpet a...        3
# 2  1198.0              Super Built up area 1198(111.3 sq.m.)        2
# 3  2290.0  Super Built up area 2290(212.75 sq.m.)Carpet a...        3
# 4   710.0                     Carpet area: 710 (65.96 sq.m.)        2
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3       3      22.0  South-West      Relatively New
# 1         3      3+       6.0         NaN  Under Construction
# 2         2       2       5.0       South      Moderately Old
# 3         4      3+      12.0  North-West      Relatively New
# 4         2       2       6.0        East      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1490.0            NaN       863.91           1             0
# 1               1730.0            NaN      1725.00           0             0
# 2               1198.0            NaN          NaN           0             0
# 3               2290.0            NaN      1800.00           1             1
# 4                  NaN            NaN       710.00           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           1       0                0           135
# 1           0           0       0                0            58
# 2           0           0       0                1           142
# 3           0           1       1                1            21
# 4           0           0       0                2            49
#
#    area_room_ratio
# 0       288.000000
# 1       576.666667
# 2       599.000000
# 3       763.333333
# 4       355.000000

# %%
train_df = df.drop(columns=['society','price_per_sqft'])

# %%
train_df.head()
# Out:
#   property_type      sector  price    area  \
# 0          flat   sector 79   1.10   864.0
# 1          flat  sector 103   1.50  1730.0
# 2          flat   sector 71   0.95  1198.0
# 3          flat  sector 104   1.75  2290.0
# 4          flat  sohna road   0.46   710.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1490(138.43 sq.m.)Carpet a...        3         3
# 1  Super Built up area 1730(160.72 sq.m.)Carpet a...        3         3
# 2              Super Built up area 1198(111.3 sq.m.)        2         2
# 3  Super Built up area 2290(212.75 sq.m.)Carpet a...        3         4
# 4                     Carpet area: 710 (65.96 sq.m.)        2         2
#
#   balcony  floorNum      facing       agePossession  super_built_up_area  \
# 0       3      22.0  South-West      Relatively New               1490.0
# 1      3+       6.0         NaN  Under Construction               1730.0
# 2       2       5.0       South      Moderately Old               1198.0
# 3      3+      12.0  North-West      Relatively New               2290.0
# 4       2       6.0        East      Relatively New                  NaN
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0            NaN       863.91           1             0           0
# 1            NaN      1725.00           0             0           0
# 2            NaN          NaN           0             0           0
# 3            NaN      1800.00           1             1           0
# 4            NaN       710.00           0             0           0
#
#    pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 0           1       0                0           135       288.000000
# 1           0       0                0            58       576.666667
# 2           0       0                1           142       599.000000
# 3           1       1                1            21       763.333333
# 4           0       0                2            49       355.000000

# %%
sns.heatmap(train_df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.heatmap(train_df.corr())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

# %%
train_df.corr()['price'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 train_df.corr()['price'].sort_values(ascending=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'flat'

# %%
# cols in question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
